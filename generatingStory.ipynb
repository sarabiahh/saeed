# %%
import pandas as pd


file_path = "/kaggle/input/cleaned/Cleaned-MSA-prompts-stories-for-fine-tuning.csv"
df = pd.read_csv(file_path)


print(df.head())
# Out:
#                                               Prompt  \
# 0  أكتب قصة قصيرة تكون مفهومة للأطفال في عمر 5-8....
# 1  أكتب قصة قصيرة تكون مفهومة للأطفال في عمر 3-5....
# 2  أكتب قصة قصيرة تكون مفهومة للأطفال في عمر 3-5....
# 3  أكتب قصة قصيرة تكون مفهومة للأطفال في عمر 3-5....
# 4  أكتب قصة قصيرة تكون مفهومة للأطفال في عمر 8-10...
#
#                                                Story
# 0  في قصرٍ عظيم في قطر، كان يعيش الأمير جمال وقطه...
# 1  في قلعة كبيرة وعتيقة في جيبوتي، كان يعيش فارس ...
# 2  في يوم مشمس جميل في الكويت، كانت هناك بطة صغير...
# 3  في بلد جميل يدعى فلسطين، كان يعيش صبي صغير يدع...
# 4  في قرية صغيرة في السودان، بينما يلف الشتاء ببر...

# %%
print(df.columns)
# Out:
# Index(['Prompt', 'Story'], dtype='object')

# %%
pip install openai==0.28
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI

client = OpenAI(api_key="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",
api_key="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")
import pandas as pd



#Define a function to generate a story
def generate_story(prompt):
    messages = [
        {"role": "system", "content": "You are an AI trained to generate Arabic children's stories based on a given description."},
        {"role": "user", "content": prompt}
    ]
    response = client.chat.completions.create(model="gpt-4",  
    messages=messages,
    temperature=0.7,
    max_tokens=2000)
    return response.choices[0].message.content

#Enter a prompt
prompt = input("Enter a prompt for the story: ")

#Generate and display the story
story = generate_story(prompt)
print("\nGenerated Story:\n")
print(story)
# Out:
# Enter a prompt for the story:  هند فتاة صغيرة تذهب الى الحديقة لتلعب مع اصدقاءها. يجب ان تكون النهاية سعيدة
# Generated Story:
#
# كانت هند فتاة صغيرة تعيش في قرية صغيرة. كانت هند تحب اللعب والاستمتاع بوقتها في الحديقة الجميلة التي كانت بالقرب من منزلها. في إحدى الأيام، قررت هند الذهاب إلى الحديقة للعب مع أصدقائها.
#
# وصلت هند إلى الحديقة ووجدت أصدقاءها ينتظرونها بفارغ الصبر. بدأوا باللعب والضحك والمرح، كانوا يلعبون بالكرة، يلوحون على الأرجوحة، و يركضون حول الأشجار. كانت هند تحب اللعب مع أصدقائها وكانت دائما تشعر بالسعادة والفرح في وجودهم.
#
# في وسط اللعب، انتبهت هند لفراشة صغيرة جميلة تحوم حول زهرة. أعجبت هند بالفراشة وقررت أن تتبعها. تابعت الفراشة حتى وصلت إلى شجرة كبيرة. وفجأة، سقطت الفراشة من الشجرة. هرعت هند لمساعدة الفراشة. بلطف، أخذت الفراشة ووضعتها على زهرة قريبة.
#
# عادت هند إلى أصدقائها وأخبرتهم عن ما حدث. كانوا جميعا مدهوشين وفخورين بها. بدأوا يطلقون عليها "هند، صديقة الفراشات". كانت هند سعيدة جدا، ليس فقط لأنها أنقذت الفراشة، ولكن أيضا لأن أصدقائها فخورون بها.
#
# ...

# %%
from openai import OpenAI

client = OpenAI(api_key="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",
api_key="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")
import pandas as pd



# Define a function to generate a story
def generate_story(prompt):
    messages = [
        {"role": "system", "content": "You are an AI trained to generate Arabic children's stories based on a given description."},
        {"role": "user", "content": prompt}
    ]
    response = client.chat.completions.create(model="gpt-4", 
    messages=messages,
    temperature=0.7,
    max_tokens=2000)
    return response.choices[0].message.content


prompt = input("Enter a prompt for the story: ")

#Generate and display the story
story = generate_story(prompt)
print("\nGenerated Story:\n")
print(story)
# Out:
# Enter a prompt for the story:   قصة قصيرة مفهومة للأطفال في عمر 6-8. أحداث القصة يجب أن تدور في المدرسة. نهاية القصة يجب أن تكون سعيدة. يجب أن يكون هناك حوار. عدد الشخصيات في القصة يجب أن يكون 2. بلد الأحداث هي مصر. يجب أن تحتوي القصة على شعور بالفخر.
# Generated Story:
#
# كان هناك طفلان في مدرسة إبتدائية في القاهرة، مصر: أحمد ومريم. كلاهما كانا في الصف الثالث الابتدائي وكانا أصدقاء حميمين.
#
# في يوم من الأيام، أعلن المعلم عن مسابقة رسم في المدرسة. كان الهدف من المسابقة تعزيز حب الوطن بين الطلاب. كان الطلاب متحمسين جدًا لهذه المسابقة.
#
# "هل ستشارك في المسابقة، أحمد؟" قالت مريم بحماس.
#
# أجاب أحمد، "بالطبع، مريم. أنا أحب الرسم وأحب بلدي مصر. سأرسم الأهرامات والنيل العظيم."
#
# بعد أسبوع، جاء يوم المسابقة. كل الطلاب رسموا بجد وإبداع. ولكن، عندما أتت النتائج، فاز أحمد بالجائزة الأولى.
#
# "مبروك، أحمد! رسمك كان رائعًا بالفعل." قالت مريم بابتسامة عريضة.
#
# "شكراً، مريم. لقد رسمت بكل حب لبلدي العظيم، مصر." أجاب أحمد بفخر.
#
# ...
